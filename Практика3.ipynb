# %% [markdown]
# <a href="https://colab.research.google.com/github/AlinaSabitova/Data_analytics_tools-/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Практика 3

# %% [markdown]
# #tFileInputDelimited

# %% [markdown]
# ![Снимок экрана 2023-10-01 204149.png](data:image/png;base64,...)

# %% [markdown]
# Считывает файл с разделителями строка за строкой, чтобы разбить их на поля, а затем отправляет поля, определенные в схеме, следующему компоненту.

# %% [markdown]
# #tFileOutputDelimited

# %% [markdown]
# ![Снимок экрана 2023-10-01 205509.png](data:image/png;base64,...)

# %% [markdown]
# Выводит входные данные в файл с разделителями в соответствии с определенной схемой.

# %% [markdown]
# #tLogRow

# %% [markdown]
# ![Снимок экрана 2023-10-01 205845.png](data:image/png;base64,...)

# %% [markdown]
# Отображает данные или результаты в консоли запуска для мониторинга обработанных данных.

# %% [markdown]
# #tMap

# %% [markdown]
# ![Снимок экрана 2023-10-01 210143.png](data:image/png;base64,...)

# %% [markdown]
# Преобразует и направляет данные из одного или нескольких источников в одно или несколько мест назначения. tMap - это продвинутый компонент, который интегрируется в качестве плагина в Talend Studio.

# %% [markdown]
# #tDBOutput

# %% [markdown]
# ![Снимок экрана 2023-10-01 210507.png](data:image/png;base64,...)

# %% [markdown]
# Записывает, обновляет, вносит изменения в записи в базе данных. Этот компонент работает с различными базами данных в зависимости от вашего выбора.

# %% [markdown]
# #tSQLTemplate

# %% [markdown]
# ![Снимок экрана 2023-10-01 212456.png](data:image/png;base64,...)

# %% [markdown]
# Выполняет общие действия с базой данных или настраиваемые шаблоны инструкций SQL, например, для удаления/создания таблицы.

# %% [markdown]
# #tFileOutputJSON

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Выводит входные данные в файл с разрешением JSON.

# %% [markdown]
# #tAggregateRow

# %% [markdown]
# ![Снимок экрана 2023-10-01 213418.png](data:image/png;base64,...)

# %% [markdown]
# Получает поток и агрегирует его на основе одного или нескольких столбцов. Для каждой выходной строки предоставляется ключ агрегации и соответствующий результат заданных операций (min, max, sum...). tAggregateRow помогает предоставить набор показателей, основанных на значениях или вычислениях.

# %% [markdown]
# #tAccessConestion

# %% [markdown]
# ![Снимок экрана 2023-10-01 214631.png](data:image/png;base64,...)

# %% [markdown]
# Открывает соединение с указанной базой данных, которое затем может быть повторно использовано в последующих вложенных заданиях. tAccess открывает подключение к базе данных для текущей транзакции.
