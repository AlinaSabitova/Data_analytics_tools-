# %% [markdown]
# <a href="https://colab.research.google.com/github/AlinaSabitova/Data_analytics_tools-/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B03_%D0%BF%D0%B5%D0%BD%D1%82%D0%B0%D1%85%D0%BE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Практика 3

# %% [markdown]
# #Delete file

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Позволяет удалить входные данные

# %% [markdown]
# CSV file input

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Позволяет загрузить файла формата CSV

# %% [markdown]
# #Text file input

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Позволяет загружать текстовые файлы

# %% [markdown]
# #JSON input

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Позволяет загружать файлы формата JSON

# %% [markdown]
# #Insert/update

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Позволяет вставлять строки или обновлять базу данных, распределенную по ключам

# %% [markdown]
# #Microsoft Excel output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Сохраняет записи в документ Excel с информацией о форматировании

# %% [markdown]
# #Sort rows

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Сортировка строк на основе значений полей (по возрастанию или по убыванию)

# %% [markdown]
# #Select values

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Позволяет выбрать или удалить поля, при необходимости задать новые поля (тип, длина, точность)

# %% [markdown]
# #Clone row

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Позволяет клонировать строку столько раз, сколько необходимо

# %% [markdown]
# #Unique rows

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Удаляет повторяющиеся строки. Работает только с отсортированными входными данными. Если входные данные не отсортированы, корректно обрабатываются только двойные последовательные строки
